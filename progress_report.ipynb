# %% [markdown]
# Github link: https://github.com/CS418/group-project-ez-squad
#
# **Any changes**: a discussion of whether your scope has changed since the check-in proposal slides. What did you aim to do that you will not do and what have you added to the project?
#
# - We had a slight change in plans due to the lack of supporting data we could gather for our original idea. We still are following the same general principles but with a more focused plan
#
#
# **Data**: an introduction that discusses in detail the data you are analyzing. Include where are you getting the data from and the original size of the data. Briefly describe each table and how they will be connected.
#
# - Ethan:
#   - Harmful Karenia brevis algae cell count. I am getting the data from, https://www.ncei.noaa.gov/maps/habsos/maps.htm.
#   - Original size: (190339, 25)
# - Khizer
#   - Bleaching levels/percentages of coral reefs
#   - source : https://www.nature.com/articles/s41597-022-01121-y
#   - Original size: (30974, 8)
#   - I am getting my data from a database that did the sepcific research but with different factors. This database has a collection of multiple sources that collected data (bleaching levels from the "Bleaching_tbl").
#     Since different sources collected data differently and the researcher added them to different columns I wrote specific queries to grab this data from certain tables. The columns that I used are Ocean_Name_LUT.Ocean_Name, Country_Name_LUT.Country_Name, Date_Year, (S1), (S2), (S3), (S4), Data_Source_LUT.Data_Source, Bleaching_tbl.Percent_Bleached from tables Data_Source_LUT, Site_Info_tbl, Ocean_Name_LUT, Country_Name_LUT,Sample_Event_tbl, Bleaching_tbl.
# -  Sean
#   * Global Fish Production
#   *   https://ourworldindata.org/fish-and-overfishing#global-fish-production
#   *   Original Size (14516, 4)
#
# - The first table shows the amount of fish pulled from the ocean over a time period. The next table represents the increase in harmful algea found on the souther coast lines in the USA. The third table represents the amount of "bleaching" happening to the coral reefs due to the lack of herbivours fish and increase in harmful algae.
#
# **Problem**: Describe the “big idea”? What is the problem you want to solve, the question you want to answer, or the decision-making you want to support? Why should others care about it? How did you choose this problem?
#
# - The big picture is to show the domino affect overfishing has on the ecosystem. Our hypothesis is with the incease of fishing, there is an icrease in harmful algae taking over with causes the coral reefs to "bleach" (partly die). We choose this problem as a group because we all have conncetions with our envirnorment and wish to keep it the way it is.
#
# **Research questions**: Describe the data science research questions you are investigating. At least one research question per team member.
# You can use this guideline to Formulate a Good Research Question For Efficient Statistical Analysis. If you use a different guideline, you must mention it and include the reference in the slide.
#
# - Ethan: What are the temporal and spatial patterns of Karenia brevis algal blooms in the Gulf of Mexico and along the eastern coast of Florida, and how do environmental factors such as water temperature, salinity, and nutrient levels affect these patterns?
#
# *   Sean: What are the trends in consumer consumption over the past 5-6 decades? How do these trends correlate to trends in algal blooms and environmental impacts? Can consumption trends be a good predictor of environmental impact?
#
# - Khizer: what are the bleaching levels trends of the coral reefs by oceans. And does these increased levels are a cause of overfishing which in turn destroying our ecosystem (marine ecosystem)?
#
#
# **Data cleaning**: show clearly how you cleaned your data, step by step. Show the original data size and the final size. Discuss how much data was lost after cleaning. At least one table is cleaned per team member.
#
# - Ethan: The data I had gathered was extensive but had some columns that I did not need. I removed columns that I did not need (dropping them). I also had to convert the SAMPLE_DATE column to date and time format. Once this was done it became very apparent there was data that didnt make anysense. I then removed all data that was marked as before 1953 and anything after that was marked 2022. Once this was done it was easy to work with and understand
#
# - Khizer: I was able to retrieve this data from a databse file and I spent extensive amount of time writing sql queries to retrieve this clean data. I selected only important columns from the db and dropped the irrelevant ones. I also had to drop rows that were marked as NuLL by the researchers as this databse consistes of mutliple collabarative researchers data. I was able to retrieve data that is required for the project by making sure I didn't had duplicates because the database is not clean rather its been put as one collection wihtout proper differentiation and different sources/researchers did their own method of calculations. So for example, one of the sources I have is by "Reef Check" and they collected bleaching levels by dividing a oceans transect into 4 levels S1,S2,S3 and S4. So I took average of these values as it would give us an approximate idea of how much a oceans transect is bleached by the corals.
#
# *   Sean: The data I collected was already well organized and did not require much cleaning. I removed the columns of data I did not need and then partitioned the data as needed. For instance, I wanted to show data by country and North America as a whole. I created separate data frames for Canada, Mexico, US, and North America. For the NA dataset I grouped the data by 'Year' and then can calculated the sum of the 'Consumption' column so that I could display aggregate cunsumption.
#
#
# **Exploratory data analysis**: explain what your data looks like (words are fine, but visualizations are often better). Include a description of each table, the statistical data type of each column, the number of rows, etc. All the columns should be analyzed. You should try to find correlations between the different attributes (visualization of the data, data distribution, or correlations.)
#
#  - Please include the author name of the EDA per table and at least one EDA per team member.
#
# - Include any interesting issues or preliminary conclusions you have about your data. All the tables should be analyzed.
#
# - Visualizations for EDA that test an interesting hypothesis, along with explanations about why you thought this was an interesting hypothesis to investigate. At least one visualization per team member for this report.
#
# Author:
# - Ethan:
#
# ![image.png](attachment:image-3.png)
#
# This graph shows the cell count of Karenia brevis algae over a time frame(1970 - 2021). As you we can observe in the yea 1995 we see a large spike of cell count in Fl. This trend seems to slowly decrease but not by much. We also note the introduction of this algae in AL and TX. TX with an unusualy spike in algae observation. Some conclusion we have come to is that during the 1990's we see a trend in increase of fishing and an increase in cell count. We also observed coral reefs beging to "bleach"
#
# - Sean:
#
# ![image.png](attachment:image-2.png)
#
# - Khizer:
#
# ![image.png](attachment:image.png)
#
# This graph shows the comparison of yearly increase in bleaching levels by the corals by oceans. The data is covering the years 1980 - 2020. This data will be used in relation to Sean and Ethan's work where we will show the affects of bleaching levels of coral health, overall disruption in the ecosystem. If a similar trend is seen from Ethan and Sean's work and my work our hypothesis is that overfishing has a impact on the bleaching levels of the coral reefs and this is affecting our marine ecosystem. Also, we can observe a Moderate bleaching levels (11-50%) and Severe level (>50%) are common in oceans like Indian, Pacific and Atlantic. The plot also shows that these Severe levels have gotten down after the year 2000 probably because of awareness. However, more testing needs to be done and based off this initial data and testing we can see a pattern match in our work.
#
# **Model planning**: write down the ML tasks that you plan to use to answer the DS research questions and explain why these tasks make sense. For each question, propose at least three ML models (for the same ML task) and analyze their pros and cons. At least three models are proposed per team member.
#
# - Ethan:
#
#   Classification:
#
#   - a. Decision Trees: Pros - easy to interpret, can handle non-linear relationships between features, can handle categorical and numerical features; Cons - can overfit to the training data, can be sensitive to small changes in the data.
#
#   - b. Random Forest: Pros - can handle complex relationships between features, can handle high-dimensional data, can reduce overfitting by averaging multiple decision trees; Cons - can be slow to train on large datasets, can be difficult to interpret compared to decision trees.
#
#   - c. Support Vector Machines (SVM): Pros - can handle non-linear relationships between features, can handle high-dimensional data, can work well with small datasets; Cons - can be slow to train on large datasets, can be sensitive to the choice of kernel function, may require tuning of hyperparameters.
#
#   Regression:
#
#   - a. Linear Regression: Pros - simple and easy to interpret, can handle both numerical and categorical features, can work well with small datasets; Cons - assumes linear relationship between features and target, may not capture non-linear relationships or interactions between features.
#
#   - b. Random Forest Regression: Pros - can handle complex relationships between features, can handle high-dimensional data, can reduce overfitting by averaging multiple decision trees; Cons - can be slow to train on large datasets, can be difficult to interpret compared to linear regression.
#
#   - c. Gradient Boosting Regression: Pros - can handle non-linear relationships between features, can handle high-dimensional data, can work well with small datasets, can be more interpretable than random forest; Cons - can be sensitive to the choice of hyperparameters, may require more training time than linear regression.
#
#   Clustering:
#
#   - a. K-Means: Pros - simple and easy to implement, can handle large datasets, can identify distinct clusters based on distance between observations; Cons - can be sensitive to the choice of initial cluster centers, may not perform well with non-spherical or overlapping clusters.
#
#   - b. Hierarchical Clustering: Pros - can handle non-spherical or overlapping clusters, can provide a dendrogram to visualize the cluster hierarchy; Cons - can be slow to compute on large datasets, can be sensitive to the choice of distance metric and linkage function.
#
#   - c. DBSCAN: Pros - can handle non-spherical or overlapping clusters, can automatically identify the number of clusters based on density; Cons - can be sensitive to the choice of distance metric and density threshold, may not perform well with high-dimensional data.
#
# * Sean:
#   * The machine learning task I will be working on involves time series analysis, which I plan to use to develop predictive models of future environmental impacts based on historical data of overfishing. Specifically, I will be using AutoRegressive, Moving Average, and Autocorrelation models to capture the patterns and trends in the data. I chose these models because they are well-suited to time series analysis and have been shown to be effective in similar projects.
# My hope is that these predictive models of the environmental impacts caused by overfishing will provide valuable insights for our project.
#
# - Khizer
#
#   Classification: This task can be used to differentiate categories based on the bleaching levels
#                   0% - Not bleached
#                   1-10% - Midly bleached
#                   11-50% - Moderately bleached
#                   >50% - Severely bleached
#                   This classification can be used to analyze the effect of overfishing on different levels
#
#     - a. Random Forest - this can be used to handle HD- data and also can handle missing data, might overfit the data if number of tress is too high/big
#
#     - b. Support Vector - can be effective for classification task and can handle non-linearl data. May not perform well with noisy data
#
#     - c. K-Nearest - simple to implement and can handle non-linear decisions. Sensitive to outliers and may require large amount of training data
#
#   Time Series Analysis: This task will be used to analyze trends and patterns in bleaching levels over time
#
#     - a. Autoregressive Integrated Moving Average (ARIMA) - simple to implement, can handle time series data with trends and seasonality. May not perform well with non-linear relationships and may require complex interactions between features
#
#     - b. Seasonal Autoregressive Integrated Moving Average (SARIMA) - similar to ARIMA, can handle missing data and outliers. May require large amount of computational resources and doesn't perform well with non-linear relationships
#
#     - c. Long Short-Term Memory (LSTM) - Can handle times series data with long-term dependencies, also handles missing data and outliers well. Requires large amount of computational resources and may be difficult to interpret
#
#   Clustering: This task will be used to group reefs into different clusters based on their bleaching levels and other features.
#
#     - a. DBSCAN - model can handle overlapping clusters and can identify the number of clusters based on density. Sensitive to choice of distance, density and may not perform well with high dimensional data
#
#     - b. Gaussian Mixture - handles overlapping clusters, provides probabilities of cluster membership. Sensitive to number of clusters.
#
#     - c. Mean-Shift - unsupervised clustering algorithm that works by identifying centroids of each cluster. Handles non-linear data, identifies clusters of different shapes and sizes. Slow and computationally expensive.
#
#
# Reflection: a discussion of the following:
# - What is the hardest part of the project that you’ve encountered so far?
#
#   * The most challenging part of the project so far has been understanding the specific data that we need to collect and figuring out how to gather it. When we changed our topic from our initial idea, this set us back in our conceptualization period. We had to spend time reassessing our research goals and identifying the data we needed to collect. Additionally, some of the datai
#
# Reflection: a discussion of the following:
# - What is the hardest part of the project that you’ve encountered so far?
#
#   * The most challenging part of the project so far has been understanding the specific data that we need to collect and figuring out how to gather it. When we changed our topic from our initial idea, this set us back in our conceptualization period. We had to spend time reassessing our research goals and identifying the data we needed to collect. Additionally, some of the data we want to collect is proving to be a bit challenging to acquire. Specifically, we are having difficulty accessing key data that is stored in an SQL database. While we have made good progress so far with the data we have collected in .csv form, we recognize that we will need to spend more time exploring ways to access this database to collect the needed data. Nonetheless, we are determined to continue making progress and will work diligently to get the data we need.
#
#
# - What are your initial insights?
#   * Initial insights are that as Americans have increased their demand for seafood, production of wild caught seafood has increased leading to detrimental effects on the environment. This increased production appears to be related to an increase in harmful algae along US coastlines. These algae blooms result from trophic cascades related to overfishing.
#
# - Are there any concrete results you can show at this point? If not, why not?
#   * At this point we would need to further evaluate our findings to confidently state concrete results. Furthermore, we are in the process of collecting more data to help analyze our hypothesis about overfishing and its relation to changes in the environment.
#
# - Going forward, what are the current biggest problems you’re facing?
#
#   * Our biggest challenge ahead is making sure that we are diligent about our analysis in order to ensure that we are not making misrepresentations with our data. Additionally, some of the data relating to the environmental impacts of overfishing has proven a bit challenging to acquire. Regardless, we are working to resolve these issues and get the needed data to complete our analysis.
#
# - Do you think you are on track with your project? If not, what parts do you need to dedicate more time to?
#   * At the moment we feel we are at a good spot. There is a lot of work ahead, but we are confident we can work together to accomplish this task. As previously mentioned, we are currently facing challenges related to data collection. Once we sort that out, we are confident we will be on track to finishing our presentation on time.
#
# - Given your initial exploration of the data, is it worth proceeding with your project, and why? If not, how are you going to change your project and why do you think it’s better than your current results?
#
#   * After our initial exploration we feel this is a topic worth further exploration. It is something we all find to be meaningful and important for people to understand. Additionally, we feel there are enough resources available to accomplish this task. We plan to stay the course with our initial plan and will continue to work towards a thorough analysis of our topic.
#
# Next steps: What do you plan to accomplish in the next month and how do you plan to evaluate whether your project achieved the goals you set for it?
# References: List all the resources you used
#
#   * With our remaining time, we plan to continue gathering the needed data. After that, we will discuss how we can analyze our findings and curate a thoughtful and concise presentation. One key aspect we need to spend more time on is exploring how our various ML models can work together to create visualizations and interactive tools that highlight key environmental impacts of overfishing.
# To evaluate if we have achieved our goal, we will analyze our process at every step to ensure that we are presenting an unbiased exploration into the environmental impacts of overfishing. Additionally, we will evaluate whether or not our presentation is clear and engaging for our audience. If we can achieve this then we believe we have accomplished our goal.
